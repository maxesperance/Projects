# %%
'''
 Fetch Song Lyrics
'''
# Out:
# '\n Fetch Song Lyrics\n'

# %%
import numpy as np
import pandas as pd
import json

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow_hub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lyricsgenius
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Need tf version >=2.0 and hub version >=0.7
import tensorflow as tf
import tensorflow_hub as hub
print("TF version: ", tf.__version__)
print("Hub version: ", hub.__version__)
# Out:
# TF version:  2.10.0
# Hub version:  0.12.0

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

# %%
import nltk
import os
import nltk.corpus

# %%
import lyricsgenius

# %%
from lyricsgenius import Genius

# %%
# Importing Porterstemmer from nltk library
import nltk
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/maxesperance/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/maxesperance/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/maxesperance/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/maxesperance/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#from lyric genius website
api_key = "jYj-E5Zy7gsLD9X2FtZYifUYgFh4gnlbJc6cnD0Fv7Q1Zpzvyva1p2amMMvYGEAp"

# %%
#view Sade songs
genius = lyricsgenius.Genius(api_key)
artist = genius.search_artist("Sade", 
max_songs=10,sort="title")
song = artist.song("Smooth Operator")
print(song.lyrics)
# Out:
# Searching for songs by Sade...
#
# Song 1: "All About Our Love"
# Song 2: "All About Our Love (Live 2011)"
# Song 3: "Babyfather"
# Song 4: "Be That Easy"
# Song 5: "Bring Me Home"
# Song 6: "Bullet Proof Soul"
# Song 7: "By Your Side"
# Song 8: "By Your Side (Ben Watt Lazy Dog Remix)"
# Song 9: "By Your Side (Cottonbelly Fola Mix)"
# Song 10: "By Your Side (Live 2001)"
#
# Reached user-specified song limit (10).
# Done. Found 10 songs.
# Searching for "Smooth Operator" by Sade...
# Done.
# Smooth Operator Lyrics[Intro]
# He's laughing with another girl
# And playing with another heart
# Placing high stakes, making hearts ache
# He's loved in seven languages
# Jukebox life, Diamond nights and ruby lights
# High in the sky
# Heaven help him when he falls
#
# [Verse 1]
# Diamond life lover boy
# He moves in space with minimum waste and maximum joy
# City lights and business nights
# When you require streetcar desire for higher heights
# [Pre-Chorus]
# ...

# %%
#Searching for an album and saving it
#album = genius.search_album("Diamond Life", "Sade")
#album.save_lyrics()

# %%
import textwrap
#print(textwrap.fill(song.lyrics))

# %%
#save lyrics to df
smooth = genius.search_song("Smooth Operator", artist.name)
so =smooth.lyrics
# Out:
# Searching for "Smooth Operator" by Sade...
# Done.

# %%
text= so
tokenized_text=sent_tokenize(text)
SO = print(tokenized_text)
# Out:
# ["Smooth Operator Lyrics[Intro]\nHe's laughing with another girl\nAnd playing with another heart\nPlacing high stakes, making hearts ache\nHe's loved in seven languages\nJukebox life, Diamond nights and ruby lights\nHigh in the sky\nHeaven help him when he falls\n\n[Verse 1]\nDiamond life lover boy\nHe moves in space with minimum waste and maximum joy\nCity lights and business nights\nWhen you require streetcar desire for higher heights\n[Pre-Chorus]\nNo place for beginners or sensitive hearts\nThe sentiment is left to chance\nNo place to be ending but somewhere to start\n\n[Chorus]\nNo need to ask\nHe's a smooth operator\nSmooth operator\nSmooth operator\nSmooth operator\n\n[Post-Chorus]\nCoast-to-coast, L.A. to Chicago: Western male\nAcross the North and South, to Key Largo: love for sale\n\n[Verse 2]\nFace-to-face, each classic case\nWe shadow box and double-cross\nYet need the chase\n\n[Pre-Chorus]\nA license to love, insurance to hold\nMelts all your memories and change into gol
# ...

# %%
len(song.lyrics)
# Out:
# 1363

# %%
# Number of lines with splitlines() method
lines = so.splitlines()
print("Number of lines: ",len(lines))
# Out:
# Number of lines:  58

# %%
# split the text
splitted_text = so.split() # default split methods splits text according to spaces
print("Splitted text: ",splitted_text)    # splitted_text is a list that includes words of text sentence
# Out:
# Splitted text:  ['Smooth', 'Operator', 'Lyrics[Intro]', "He's", 'laughing', 'with', 'another', 'girl', 'And', 'playing', 'with', 'another', 'heart', 'Placing', 'high', 'stakes,', 'making', 'hearts', 'ache', "He's", 'loved', 'in', 'seven', 'languages', 'Jukebox', 'life,', 'Diamond', 'nights', 'and', 'ruby', 'lights', 'High', 'in', 'the', 'sky', 'Heaven', 'help', 'him', 'when', 'he', 'falls', '[Verse', '1]', 'Diamond', 'life', 'lover', 'boy', 'He', 'moves', 'in', 'space', 'with', 'minimum', 'waste', 'and', 'maximum', 'joy', 'City', 'lights', 'and', 'business', 'nights', 'When', 'you', 'require', 'streetcar', 'desire', 'for', 'higher', 'heights', '[Pre-Chorus]', 'No', 'place', 'for', 'beginners', 'or', 'sensitive', 'hearts', 'The', 'sentiment', 'is', 'left', 'to', 'chance', 'No', 'place', 'to', 'be', 'ending', 'but', 'somewhere', 'to', 'start', '[Chorus]', 'No', 'need', 'to', 'ask', "He's", 'a', 'smooth', 'operator', 'Smooth', 'operator', 'Smooth', 'operator', 'Smooth', 'operator', '[Po
# ...

# %%
import os

# %%
# words which end with "r": endswith() method finds last letter of word
words_end_with_o =  [word for word in splitted_text if word.endswith("r")]
print("words end with o: ",words_end_with_o)
# Out:
# words end with o:  ['Operator', 'another', 'another', 'lover', 'streetcar', 'for', 'higher', 'for', 'or', 'operator', 'operator', 'operator', 'operator', 'for', 'your', 'operator', 'operator', 'operator', 'operator', 'for', 'operator', 'operator', 'operator', 'operator', 'operator', 'operator']

# %%
#Word tokenizer breaks text paragraph into words.
tokenized_word=word_tokenize(so)
print(tokenized_word)
# Out:
# ['Smooth', 'Operator', 'Lyrics', '[', 'Intro', ']', 'He', "'s", 'laughing', 'with', 'another', 'girl', 'And', 'playing', 'with', 'another', 'heart', 'Placing', 'high', 'stakes', ',', 'making', 'hearts', 'ache', 'He', "'s", 'loved', 'in', 'seven', 'languages', 'Jukebox', 'life', ',', 'Diamond', 'nights', 'and', 'ruby', 'lights', 'High', 'in', 'the', 'sky', 'Heaven', 'help', 'him', 'when', 'he', 'falls', '[', 'Verse', '1', ']', 'Diamond', 'life', 'lover', 'boy', 'He', 'moves', 'in', 'space', 'with', 'minimum', 'waste', 'and', 'maximum', 'joy', 'City', 'lights', 'and', 'business', 'nights', 'When', 'you', 'require', 'streetcar', 'desire', 'for', 'higher', 'heights', '[', 'Pre-Chorus', ']', 'No', 'place', 'for', 'beginners', 'or', 'sensitive', 'hearts', 'The', 'sentiment', 'is', 'left', 'to', 'chance', 'No', 'place', 'to', 'be', 'ending', 'but', 'somewhere', 'to', 'start', '[', 'Chorus', ']', 'No', 'need', 'to', 'ask', 'He', "'s", 'a', 'smooth', 'operator', 'Smooth', 'operator', 'Smooth'
# ...

# %%
fdist = FreqDist(tokenized_word)
print(fdist)
# Out:
# <FreqDist with 134 samples and 256 outcomes>

# %%
# Frequency Distribution Plot
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
fdist.most_common(2)
# Out:
# [('Smooth', 14), ('operator', 14)]

# %%
fdist1 = FreqDist(so)
fdist1
# Out:
# FreqDist({' ': 166, 'o': 137, 'e': 122, 't': 94, 'r': 81, 'a': 78, 's': 76, 'h': 69, '\n': 57, 'i': 51, ...})

# %%
# To find the frequency of top words
fdist2 = fdist.most_common(10)
fdist2
# Out:
# [('Smooth', 14),
#  ('operator', 14),
#  ('to', 11),
#  ('[', 10),
#  (']', 10),
#  (',', 8),
#  ('and', 7),
#  ('He', 5),
#  ("'s", 4),
#  ('the', 4)]

# %%
# words which starts with "L": startswith() method
words_start_with_w = [word for word in splitted_text if word.startswith("l")]
print("words start with w: ",words_start_with_w)
# Out:
# words start with w:  ['laughing', 'loved', 'languages', 'life,', 'lights', 'life', 'lover', 'lights', 'left', 'love', 'license', 'love,', 'like', 'like[Chorus]', 'love']

# %%
# unique with set() method
#print("unique words: ",set(splitted_text))

# %%
# make all letters lowercase with lower() method
lowercase_text = [word.lower() for word in splitted_text]
#lowercase_text

# %%
#find uniques again with set() method
print("unique words: ",set(lowercase_text))
# Out:
# unique words:  {'cold', 'falls', '1]', 'ending', 'languages', 'laughing', '[chorus]', 'angels;', 'melts', 'like', 'also', 'eyes', 'across', 'stakes,', 'sale', 'ruby', 'the', 'jukebox', 'left', 'south,', 'city', 'insurance', 'joy', 'or', 'operator26embed', 'sky', 'operator', 'require', 'heaven', 'space', 'making', 'hold', 'sensitive', 'lights', 'place', 'streetcar', 'l.a.', 'change', 'when', 'love', 'coast-to-coast,', 'we', 'but', 'nights', '2]', 'like[chorus]', 'might', '[outro]', 'license', 'hearts', 'a', 'largo:', 'north', 'double-cross', 'maximum', 'diamond', 'minimum', 'ache', 'ask', 'western', 'into', 'his', 'gold', '[verse', 'is', 'be', 'boy', 'are', 'high', 'loved', 'smooth', 'another', 'start', 'in', 'no', 'with', 'moves', 'case', 'playing', 'key', 'to', 'placing', 'him', 'waste', 'seven', 'heights', 'chicago:', 'business', 'need', 'all', 'life', 'shadow', 'help', "he's", 'you', '[post-chorus]', 'sentiment', 'girl', 'desire', 'male', 'memories', 'each', 'love,', 'life,', 'cha
# ...

# %%
# check words are upper case or lower case
print("Is word uppercase:", "Smooth".isupper())
print("Is word lowercase:", "need".islower())
# Out:
# Is word uppercase: False
# Is word lowercase: True

# %%
# Checking for the list of letters
stm = ["o", "e", "t"]
for word in so :
   print(word)
# Out:
# S
# m
# o
# o
# t
# h
#
# O
# p
# e
# r
# a
# t
# o
# r
#
# L
# y
# r
# i
# c
# s
# [
# I
# n
# t
# r
# o
# ]
#
#
# H
# e
# '
# s
#
# l
# a
# u
# g
# h
# i
# n
# g
#
# w
# i
# t
# h
#
# a
# n
# o
# t
# h
# e
# r
#
# g
# i
# r
# l
#
#
# A
# n
# d
#
# p
# l
# a
# y
# i
# n
# g
#
# w
# i
# t
# h
#
# a
# n
# o
# t
# h
# e
# r
#
# h
# e
# a
# r
# t
#
#
# P
# l
# a
# c
# i
# n
# g
#
# h
# i
# g
# h
#
# s
# t
# a
# k
# e
# s
# ,
#
# m
# a
# k
# i
# n
# g
#
# h
# e
# a
# r
# t
# s
#
# a
# c
# h
# e
#
#
# H
# e
# '
# s
#
# l
# o
# v
# e
# d
#
# i
# n
#
# s
# e
# v
# e
# n
#
# l
# a
# n
# g
# u
# a
# g
# e
# s
#
#
# J
# u
# k
# e
# b
# o
# x
#
# l
# i
# f
# e
# ,
#
# D
# i
# a
# m
# o
# n
# d
#
# n
# i
# g
# h
# t
# s
#
# a
# n
# d
#
# r
# u
# b
# y
#
# l
# i
# g
# h
# t
# s
#
#
# H
# i
# g
# h
#
# i
# n
#
# t
# h
# e
#
# s
# k
# y
#
#
# H
# e
# a
# v
# e
# n
#
# h
# e
# l
# p
#
# h
# i
# m
#
# w
# h
# e
# n
#
# h
# e
#
# f
# a
# l
# l
# s
#
#
#
#
# [
# V
# e
# r
# s
# e
#
# 1
# ]
#
#
# D
# i
# ...

# %%
# Cleaning text
text1 = so
print("Split text: ",text1.split(" "))   # as you can see there are unnecessary white space in list

# get rid of from these unnecassary white spaces with strip() method then split
print("Cleaned text: ",text1.strip().split(" "))
# Out:
# Split text:  ['Smooth', 'Operator', "Lyrics[Intro]\nHe's", 'laughing', 'with', 'another', 'girl\nAnd', 'playing', 'with', 'another', 'heart\nPlacing', 'high', 'stakes,', 'making', 'hearts', "ache\nHe's", 'loved', 'in', 'seven', 'languages\nJukebox', 'life,', 'Diamond', 'nights', 'and', 'ruby', 'lights\nHigh', 'in', 'the', 'sky\nHeaven', 'help', 'him', 'when', 'he', 'falls\n\n[Verse', '1]\nDiamond', 'life', 'lover', 'boy\nHe', 'moves', 'in', 'space', 'with', 'minimum', 'waste', 'and', 'maximum', 'joy\nCity', 'lights', 'and', 'business', 'nights\nWhen', 'you', 'require', 'streetcar', 'desire', 'for', 'higher', 'heights\n[Pre-Chorus]\nNo', 'place', 'for', 'beginners', 'or', 'sensitive', 'hearts\nThe', 'sentiment', 'is', 'left', 'to', 'chance\nNo', 'place', 'to', 'be', 'ending', 'but', 'somewhere', 'to', 'start\n\n[Chorus]\nNo', 'need', 'to', "ask\nHe's", 'a', 'smooth', 'operator\nSmooth', 'operator\nSmooth', 'operator\nSmooth', 'operator\n\n[Post-Chorus]\nCoast-to-coast,', 'L.A.', 'to',
# ...

# %%
# normalization
words = so
words_list = words.lower().split(" ")
#print("normalized words: ",words_list)

# %%
import nltk as nlp

# %%
# stemming
porter_stemmer = nlp.PorterStemmer()
roots = [porter_stemmer.stem(each) for each in words_list]
print("roots of task Tasked tasks tasking: ",roots)
# Out:
# roots of task Tasked tasks tasking:  ['smooth', 'oper', "lyrics[intro]\nhe'", 'laugh', 'with', 'anoth', 'girl\nand', 'play', 'with', 'anoth', 'heart\nplac', 'high', 'stakes,', 'make', 'heart', "ache\nhe'", 'love', 'in', 'seven', 'languages\njukebox', 'life,', 'diamond', 'night', 'and', 'rubi', 'lights\nhigh', 'in', 'the', 'sky\nheaven', 'help', 'him', 'when', 'he', 'falls\n\n[vers', '1]\ndiamond', 'life', 'lover', 'boy\nh', 'move', 'in', 'space', 'with', 'minimum', 'wast', 'and', 'maximum', 'joy\nciti', 'light', 'and', 'busi', 'nights\nwhen', 'you', 'requir', 'streetcar', 'desir', 'for', 'higher', 'heights\n[pre-chorus]\nno', 'place', 'for', 'beginn', 'or', 'sensit', 'hearts\nth', 'sentiment', 'is', 'left', 'to', 'chance\nno', 'place', 'to', 'be', 'end', 'but', 'somewher', 'to', 'start\n\n[chorus]\nno', 'need', 'to', "ask\nhe'", 'a', 'smooth', 'operator\nsmooth', 'operator\nsmooth', 'operator\nsmooth', 'operator\n\n[post-chorus]\ncoast-to-coast,', 'l.a.', 'to', 'chicago:', 'western',
# ...

# %%
# stemming
stemming_word_list = so
porter_stemmer = nlp.PorterStemmer()
roots = [porter_stemmer.stem(each) for each in stemming_word_list]
print("result of stemming: ",roots)
# Out:
# result of stemming:  ['S', 'm', 'o', 'o', 't', 'h', ' ', 'O', 'p', 'e', 'r', 'a', 't', 'o', 'r', ' ', 'L', 'y', 'r', 'i', 'c', 's', '[', 'I', 'n', 't', 'r', 'o', ']', '\n', 'H', 'e', "'", 's', ' ', 'l', 'a', 'u', 'g', 'h', 'i', 'n', 'g', ' ', 'w', 'i', 't', 'h', ' ', 'a', 'n', 'o', 't', 'h', 'e', 'r', ' ', 'g', 'i', 'r', 'l', '\n', 'A', 'n', 'd', ' ', 'p', 'l', 'a', 'y', 'i', 'n', 'g', ' ', 'w', 'i', 't', 'h', ' ', 'a', 'n', 'o', 't', 'h', 'e', 'r', ' ', 'h', 'e', 'a', 'r', 't', '\n', 'P', 'l', 'a', 'c', 'i', 'n', 'g', ' ', 'h', 'i', 'g', 'h', ' ', 's', 't', 'a', 'k', 'e', 's', ',', ' ', 'm', 'a', 'k', 'i', 'n', 'g', ' ', 'h', 'e', 'a', 'r', 't', 's', ' ', 'a', 'c', 'h', 'e', '\n', 'H', 'e', "'", 's', ' ', 'l', 'o', 'v', 'e', 'd', ' ', 'i', 'n', ' ', 's', 'e', 'v', 'e', 'n', ' ', 'l', 'a', 'n', 'g', 'u', 'a', 'g', 'e', 's', '\n', 'J', 'u', 'k', 'e', 'b', 'o', 'x', ' ', 'l', 'i', 'f', 'e', ',', ' ', 'D', 'i', 'a', 'm', 'o', 'n', 'd', ' ', 'n', 'i', 'g', 'h', 't', 's', ' ', 'a', 'n', '
# ...

# %%
tags = nltk.pos_tag(so)
tags
# Out:
# [('S', 'NNP'),
#  ('m', 'NN'),
#  ('o', 'NN'),
#  ('o', 'NN'),
#  ('t', 'NN'),
#  ('h', 'NN'),
#  (' ', 'NNP'),
#  ('O', 'NNP'),
#  ('p', 'NN'),
#  ('e', 'NN'),
#  ('r', 'VBZ'),
#  ('a', 'DT'),
#  ('t', 'NN'),
#  ('o', 'NN'),
#  ('r', 'NN'),
#  (' ', 'NNP'),
#  ('L', 'NNP'),
#  ('y', 'NNP'),
#  ('r', 'NN'),
#  ('i', 'NN'),
#  ('c', 'VBP'),
#  ('s', 'JJ'),
#  ('[', 'NN'),
#  ('I', 'PRP'),
#  ('n', 'VBP'),
#  ('t', 'JJ'),
#  ('r', 'NN'),
#  ('o', 'NN'),
#  (']', 'NNP'),
#  ('\n', 'NNP'),
#  ('H', 'NNP'),
#  ('e', 'NN'),
#  ("'", "''"),
#  ('s', 'JJ'),
#  (' ', 'NNP'),
#  ('l', 'NN'),
#  ('a', 'DT'),
#  ('u', 'JJ'),
#  ('g', 'NN'),
#  ('h', 'NN'),
#  ('i', 'JJ'),
#  ('n', 'VBP'),
#  ('g', 'JJ'),
#  (' ', 'NNP'),
#  ('w', 'NN'),
#  ('i', 'NN'),
#  ('t', 'VBP'),
#  ('h', 'NN'),
#  (' ', 'VBP'),
#  ('a', 'DT'),
#  ('n', 'JJ'),
#  ('o', 'NN'),
#  ('t', 'NN'),
#  ('h', 'NN'),
#  ('e', 'NN'),
#  ('r', 'NN'),
#  (' ', 'NNP'),
#  ('g', 'NN'),
#  ('i', 'NN'),
#  ('r', 'VBP'),
#  ('l', 'NN'),
# ...

# %%
#pip install tdm

# %%
#import tdm

# %%
# lemmatization
lemma = nlp.WordNetLemmatizer()
lemma_roots = [lemma.lemmatize(each) for each in stemming_word_list]
print("result of lemmatization: ",lemma_roots)
# Out:
# result of lemmatization:  ['S', 'm', 'o', 'o', 't', 'h', ' ', 'O', 'p', 'e', 'r', 'a', 't', 'o', 'r', ' ', 'L', 'y', 'r', 'i', 'c', 's', '[', 'I', 'n', 't', 'r', 'o', ']', '\n', 'H', 'e', "'", 's', ' ', 'l', 'a', 'u', 'g', 'h', 'i', 'n', 'g', ' ', 'w', 'i', 't', 'h', ' ', 'a', 'n', 'o', 't', 'h', 'e', 'r', ' ', 'g', 'i', 'r', 'l', '\n', 'A', 'n', 'd', ' ', 'p', 'l', 'a', 'y', 'i', 'n', 'g', ' ', 'w', 'i', 't', 'h', ' ', 'a', 'n', 'o', 't', 'h', 'e', 'r', ' ', 'h', 'e', 'a', 'r', 't', '\n', 'P', 'l', 'a', 'c', 'i', 'n', 'g', ' ', 'h', 'i', 'g', 'h', ' ', 's', 't', 'a', 'k', 'e', 's', ',', ' ', 'm', 'a', 'k', 'i', 'n', 'g', ' ', 'h', 'e', 'a', 'r', 't', 's', ' ', 'a', 'c', 'h', 'e', '\n', 'H', 'e', "'", 's', ' ', 'l', 'o', 'v', 'e', 'd', ' ', 'i', 'n', ' ', 's', 'e', 'v', 'e', 'n', ' ', 'l', 'a', 'n', 'g', 'u', 'a', 'g', 'e', 's', '\n', 'J', 'u', 'k', 'e', 'b', 'o', 'x', ' ', 'l', 'i', 'f', 'e', ',', ' ', 'D', 'i', 'a', 'm', 'o', 'n', 'd', ' ', 'n', 'i', 'g', 'h', 't', 's', ' ', 'a', '
# ...

# %%
# Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in so:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",so)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: Smooth Operator Lyrics[Intro]
# He's laughing with another girl
# And playing with another heart
# Placing high stakes, making hearts ache
# He's loved in seven languages
# Jukebox life, Diamond nights and ruby lights
# High in the sky
# Heaven help him when he falls
#
# [Verse 1]
# Diamond life lover boy
# He moves in space with minimum waste and maximum joy
# City lights and business nights
# When you require streetcar desire for higher heights
# [Pre-Chorus]
# No place for beginners or sensitive hearts
# The sentiment is left to chance
# No place to be ending but somewhere to start
#
# [Chorus]
# No need to ask
# He's a smooth operator
# Smooth operator
# Smooth operator
# Smooth operator
#
# [Post-Chorus]
# Coast-to-coast, L.A. to Chicago: Western male
# Across the North and South, to Key Largo: love for sale
#
# [Verse 2]
# Face-to-face, each classic case
# We shadow box and double-cross
# Yet need the chase
#
# [Pre-Chorus]
# ...

# %%
#Lexicon Normalization
#performing stemming and Lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()

so = so
print("Lemmatized Word:",lem.lemmatize(so))
# Out:
# Lemmatized Word: Smooth Operator Lyrics[Intro]
# He's laughing with another girl
# And playing with another heart
# Placing high stakes, making hearts ache
# He's loved in seven languages
# Jukebox life, Diamond nights and ruby lights
# High in the sky
# Heaven help him when he falls
#
# [Verse 1]
# Diamond life lover boy
# He moves in space with minimum waste and maximum joy
# City lights and business nights
# When you require streetcar desire for higher heights
# [Pre-Chorus]
# No place for beginners or sensitive hearts
# The sentiment is left to chance
# No place to be ending but somewhere to start
#
# [Chorus]
# No need to ask
# He's a smooth operator
# Smooth operator
# Smooth operator
# Smooth operator
#
# [Post-Chorus]
# Coast-to-coast, L.A. to Chicago: Western male
# Across the North and South, to Key Largo: love for sale
#
# [Verse 2]
# Face-to-face, each classic case
# We shadow box and double-cross
# Yet need the chase
#
# [Pre-Chorus]
# ...

# %%
print("Stemmed Word:",stem.stem(so))
# Out:
# Stemmed Word: smooth operator lyrics[intro]
# he's laughing with another girl
# and playing with another heart
# placing high stakes, making hearts ache
# he's loved in seven languages
# jukebox life, diamond nights and ruby lights
# high in the sky
# heaven help him when he falls
#
# [verse 1]
# diamond life lover boy
# he moves in space with minimum waste and maximum joy
# city lights and business nights
# when you require streetcar desire for higher heights
# [pre-chorus]
# no place for beginners or sensitive hearts
# the sentiment is left to chance
# no place to be ending but somewhere to start
#
# [chorus]
# no need to ask
# he's a smooth operator
# smooth operator
# smooth operator
# smooth operator
#
# [post-chorus]
# coast-to-coast, l.a. to chicago: western male
# across the north and south, to key largo: love for sale
#
# [verse 2]
# face-to-face, each classic case
# we shadow box and double-cross
# yet need the chase
#
# [pre-chorus]
# a license to love, insurance to hold
# ...
